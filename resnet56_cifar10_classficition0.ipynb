# %% [markdown]
# <a href="https://colab.research.google.com/github/painterner/colabTest/blob/master/resnet56_cifar10_classficition0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  # !pip install "tensorflow_hub>=0.6.0"
  # !pip install "tensorflow-gpu>=2.0.0"

  import tensorflow as tf
  import tensorflow_hub as hub

  from PIL import Image
  import numpy as np
  import matplotlib.pyplot as plt
  import os,sys
# Out:
# ...
#      |████████████████████████████████| 380.8MB 46kB/s
# ...
#      |████████████████████████████████| 3.8MB 40.2MB/s
# ...
#      |████████████████████████████████| 450kB 62.9MB/s
# ...
#      |████████████████████████████████| 81kB 12.2MB/s
# ...
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 2.0.2 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 2.0.1 which is incompatible.
# ERROR: tensorboard 2.0.2 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.4.0, but you'll have google-auth 1.10.0 which is incompatible.
# ...
#   Found existing installation: google-auth 1.4.2
#     Uninstalling google-auth-1.4.2:
#       Successfully uninstalled google-auth-1.4.2
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
# ...

# %%
# image_url="https://github.com/painterner/resources/blob/master/Screenshot%20from%202018-10-22%2011-35-02.png?raw=true"
# !wget $image_url -O test_image.png

# test_img = Image.open('./test_image.png')
# image_tensor = test_img

# %%
# # Apply image detector on a single image.
# detector = hub.Module("https://tfhub.dev/google/openimages_v4/ssd/mobilenet_v2/1")
# detector_output = detector(image_tensor, as_dict=True)
# class_names = detector_output["detection_class_names"]


# # module_url = "https://tfhub.dev/google/openimages_v4/ssd/mobilenet_v2/1"
# detector = hub.load(module_url)
# # print(detector.shape)  #(3,128)


# detector_output = detector(image_tensor, as_dict=True)
# class_names = detector_output["detection_class_names"]

# %%
  # !git clone https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 33497 (delta 1), reused 13 (delta 0), pack-reused 33482
# Receiving objects: 100% (33497/33497), 511.88 MiB | 36.11 MiB/s, done.
# Resolving deltas: 100% (21414/21414), done.
# Checking out files: 100% (3194/3194), done.

# %%
import os
os.environ['PYTHONPATH'] += ":/content/models"

# %%
  # !pip3 install --user -r /content/models/official/requirements.txt
  # !python /content/models/official/r1/resnet/cifar10_download_and_extract.py

# %%
cd models/official/vision/image_classification/
# Out:
# /content/models/official/vision/image_classification

# %%
# !python resnet_cifar_main.py --data_dir=/tmp/cifar10_data
# !python resnet_cifar_main.py --train_epochs=100
# Out:
# 2019-12-31 07:04:50.550089: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2019-12-31 07:04:50.555097: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000175000 Hz
# 2019-12-31 07:04:50.555307: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1e412c0 executing computations on platform Host. Devices:
# 2019-12-31 07:04:50.555339: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2019-12-31 07:04:50.557261: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-31 07:04:50.642473: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
